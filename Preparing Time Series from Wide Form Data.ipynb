# %% [markdown]
# **Task - Part 1**

# %% [markdown]
# First, you will prepare the dataset for time series analysis:
#
#     -Load in the Zillow Home Value Index dataframe.
#         -Note: it is a large file and may take a minute to load.
#     -Filter the 4 largest cities into a new dataframe.
#         -Tip: the "SizeRank" column has already ranked the cities by size. The larger the city, the smaller the rank value.
#         -Therefore the 4 largest cities would have rank values of [0,1,2,3]
#
#     -Melt the data to long-form and prepare it for time series analysis.
#         -Convert the melted dates into datetime datatype.
#         -Make the datetime column the index.
#     -Resample the dataframe as monthly frequency, grouped by City.

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticks
import matplotlib.pyplot as plt
import seaborn as sns
import os
# set random seed
SEED = 321
np.random.seed(SEED)

# %%
df = pd.read_csv('Data/City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
df.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
# 4          San Antonio-New Braunfels, TX        Bexar County    114794.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22467 entries, 0 to 22466
# Data columns (total 281 columns):
#  #    Column      Dtype
# ---   ------      -----
#  0    RegionID    int64
#  1    SizeRank    int64
#  2    RegionName  object
#  3    RegionType  object
#  4    StateName   object
#  5    State       object
#  6    Metro       object
#  7    CountyName  object
#  8    2000-01-31  float64
#  9    2000-02-29  float64
#  10   2000-03-31  float64
#  11   2000-04-30  float64
#  12   2000-05-31  float64
#  13   2000-06-30  float64
#  14   2000-07-31  float64
#  15   2000-08-31  float64
#  16   2000-09-30  float64
#  17   2000-10-31  float64
#  18   2000-11-30  float64
#  19   2000-12-31  float64
#  20   2001-01-31  float64
#  21   2001-02-28  float64
#  22   2001-03-31  float64
#  23   2001-04-30  float64
#  24   2001-05-31  float64
#  25   2001-06-30  float64
#  26   2001-07-31  float64
#  27   2001-08-31  float64
#  28   2001-09-30  float64
#  29   2001-10-31  float64
# ...

# %%
df.shape
# Out:
# (22467, 281)

# %% [markdown]
# **Filter the 4 largest cities into a new dataframe**

# %%
#Create a copy of the dataframe
dff = df.copy()

# %%
#Filter
four_largest_cities = (dff['SizeRank'] >= 0) & (dff['SizeRank'] <=3)

# %%
dff[four_largest_cities]
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# 1    234401.0  ...    924019.0    928991.0    937936.0    953874.0
# 2    109079.0  ...    245783.0    248718.0    252080.0    256435.0
# ...

# %%
#Filter
dff = dff[four_largest_cities]
dff
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# 1    234401.0  ...    924019.0    928991.0    937936.0    953874.0
# 2    109079.0  ...    245783.0    248718.0    252080.0    256435.0
# ...

# %% [markdown]
# **Melt the data to long-form and prepare it for time series analysis**

# %%
dff.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'CountyName', '2000-01-31', '2000-02-29',
#        ...
#        '2021-12-31', '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#        '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31', '2022-09-30'],
#       dtype='object', length=281)

# %%
melt = pd.melt(dff.drop(columns=['RegionID','StateName']),
                 id_vars=['SizeRank', 'RegionName','RegionType','State','Metro','CountyName'],
                value_name='Home Value',var_name="Date")
melt
# Out:
#       SizeRank   RegionName RegionType State  \
# 0            0     New York       city    NY
# 1            1  Los Angeles       city    CA
# 2            2      Houston       city    TX
# 3            3      Chicago       city    IL
# 4            0     New York       city    NY
# ...        ...          ...        ...   ...
# 1087         3      Chicago       city    IL
# 1088         0     New York       city    NY
# 1089         1  Los Angeles       city    CA
# 1090         2      Houston       city    TX
# 1091         3      Chicago       city    IL
#
#                                       Metro          CountyName        Date  \
# 0     New York-Newark-Jersey City, NY-NJ-PA       Queens County  2000-01-31
# 1        Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  2000-01-31
# 2      Houston-The Woodlands-Sugar Land, TX       Harris County  2000-01-31
# 3        Chicago-Naperville-Elgin, IL-IN-WI         Cook County  2000-01-31
# ...

# %% [markdown]
# **Convert the melted dates into datetime datatype**

# %%
melt['Date'] = pd.to_datetime(melt['Date'])
melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SizeRank    1092 non-null   int64
#  1   RegionName  1092 non-null   object
#  2   RegionType  1092 non-null   object
#  3   State       1092 non-null   object
#  4   Metro       1092 non-null   object
#  5   CountyName  1092 non-null   object
#  6   Date        1092 non-null   datetime64[ns]
#  7   Home Value  1087 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 68.4+ KB

# %% [markdown]
# **Make the datetime column the index**

# %%
melt = melt.set_index("Date")
melt
# Out:
#             SizeRank   RegionName RegionType State  \
# Date
# 2000-01-31         0     New York       city    NY
# 2000-01-31         1  Los Angeles       city    CA
# 2000-01-31         2      Houston       city    TX
# 2000-01-31         3      Chicago       city    IL
# 2000-02-29         0     New York       city    NY
# ...              ...          ...        ...   ...
# 2022-08-31         3      Chicago       city    IL
# 2022-09-30         0     New York       city    NY
# 2022-09-30         1  Los Angeles       city    CA
# 2022-09-30         2      Houston       city    TX
# 2022-09-30         3      Chicago       city    IL
#
#                                             Metro          CountyName  \
# Date
# 2000-01-31  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# 2000-01-31     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
# 2000-01-31   Houston-The Woodlands-Sugar Land, TX       Harris County
# ...

# %% [markdown]
# **Resample the dataframe as monthly frequency, grouped by City.**

# %%
dff_ts = melt.groupby('RegionName').resample("M").sum()
dff_ts
# Out:
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_36248/2745135385.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dff_ts = melt.groupby('RegionName').resample("M").sum()
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_36248/2745135385.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dff_ts = melt.groupby('RegionName').resample("M").sum()
# ...

# %% [markdown]
# **Task - Part 2**

# %% [markdown]
#     -Once you've prepared the dataframe with the time series data for the 4 largest cities:
#
#         -Plot the home values for all 4 cities. (Hint: use unstack)
#             -Make sure to add a title and axis labels.
#             -Reformat the y-axis ticks to use thousands of dollars with a "K" at the end. (e.g. "200K, 400K, etc")
#                 -Hint: use the FuncFormatter from matplotlib.
#
#         -Answer the following 2 questions using pandas:
#
#             -1) Which City had the highest Typical Home Value at the end of 2008? Which had the least?
#
#                 -Hint: You can use the unstacked dataframe or use pd.IndexSlice with the multiindex.
#
#             -2) How much did the home values change from November 2008 to December 2008 (in dollars)?
#
#                 -Hint: you can use .diff() to calculate the change in values

# %% [markdown]
# **Plot the home values for all 4 cities**

# %%
#Function to convert thousands into K
def thousands(x,pos):
    """function for use wth matplotlib FuncFormatter -  formats money in millions"""
    new_x = x/1_000
    return f"{new_x:,.0f}K"

#Create the formatter
fmt_thous = mticks.FuncFormatter(thousands)

# %%
#Unstack each city
unstack = dff_ts.unstack(0)

# %%
unstack
# Out:
#            SizeRank                              Home Value            \
# RegionName  Chicago Houston Los Angeles New York    Chicago   Houston
# Date
# 2000-01-31        3       2           1        0   166139.0  109068.0
# 2000-02-29        3       2           1        0   166536.0  109079.0
# 2000-03-31        3       2           1        0   167368.0  108878.0
# 2000-04-30        3       2           1        0   168826.0  108881.0
# 2000-05-31        3       2           1        0   170499.0  108834.0
# ...             ...     ...         ...      ...        ...       ...
# 2022-05-31        3       2           1        0   312487.0  265558.0
# 2022-06-30        3       2           1        0   314663.0  268901.0
# 2022-07-31        3       2           1        0   315910.0  271059.0
# 2022-08-31        3       2           1        0   315587.0  272400.0
# 2022-09-30        3       2           1        0   315429.0  272639.0
#
#
# RegionName Los Angeles  New York
# Date
# ...

# %%
unstack.drop('SizeRank', axis=1, inplace=True)

# %%
ax = unstack['Home Value'].plot(figsize=(12,5))
ax.yaxis.set_major_formatter(fmt_thous)
ax.set_title('Home Values for 4 Largest Cities')
ax.set_xlabel('Date')
ax.set_ylabel('$ Dollars');

# %% [markdown]
# **Question 1: Which City had the highest Typical Home Value at the end of 2008? Which had the least?**

# %%
unstack.head()
# Out:
#            Home Value
# RegionName    Chicago   Houston Los Angeles  New York
# Date
# 2000-01-31   166139.0  109068.0    234181.0  253690.0
# 2000-02-29   166536.0  109079.0    234401.0  255517.0
# 2000-03-31   167368.0  108878.0    235513.0  257207.0
# 2000-04-30   168826.0  108881.0    237589.0  260310.0
# 2000-05-31   170499.0  108834.0    240113.0  263204.0

# %%
# Get max value and index
min = unstack.idxmin()
index = unstack.loc['2008-12'].idxmax()[1]
unstack.loc[index]
# Out:
#             RegionName
# Home Value  Chicago        265306.0
#             Houston        131283.0
#             Los Angeles    469294.0
#             New York       510309.0
# Name: 2008-12-31 00:00:00, dtype: float64

# %% [markdown]
# New York had the highest typical home value at the end of 2008. Home value for New York was $510,309.
#
# Houston had the lowest typical home value at the end of 2008. Home value for Houston was $131,283.

# %%
#Plot all cities

ax = unstack['Home Value'].plot(figsize=(12,5))
ax.yaxis.set_major_formatter(fmt_thous)
ax.set_title('Home Values for 4 Largest Cities')
ax.vlines(index,0,1000000, colors='k', linestyles='dashed')
ax.yaxis.set_major_formatter(fmt_thous)
ax.set_xlabel('Date')
ax.set_ylabel('$ Dollars');

# %% [markdown]
# **Question 2: How much did the home values change from November 2008 to December 2008 (in dollars)?**

# %%
#Difference between Nov to Dec 2008
difference2008 = unstack.loc['nov 2008':'dec 2008'].diff().dropna()
difference2008
# Out:
#            Home Value
# RegionName    Chicago Houston Los Angeles New York
# Date
# 2008-12-31    -5753.0  -964.0    -12611.0  -4458.0

# %% [markdown]
# For each city home values went down from November 2008 to December 2008.
#
# Chicago homes lost $5,753.
#
# Houston homes lost $964.
#
# Los Angeles homes lost $12,611.
#
# New York homes lost $4,458.
#
# Not a great year for home values.
